# %%
from datasets import load_dataset
ds = load_dataset("lambdalabs/pokemon-blip-captions", split="train")
sample = ds[0]
display(sample["image"].resize((256, 256)))
print(sample["text"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_dataset
#       2 ds = load_dataset("lambdalabs/pokemon-blip-captions", split="train")
# ----> 3 sample = ds[0]
#       4 display(sample["image"].resize((256, 256)))
#       5 print(sample["text"])
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\arrow_dataset.py:2803, in Dataset.__getitem__(self, key)
#    2801 def __getitem__(self, key):  # noqa: F811
#    2802     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2803     return self._getitem(key)
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\arrow_dataset.py:2788, in Dataset._getitem(self, key, **kwargs)
#    2786 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2787 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2788 formatted_output = format_table(
#    2789     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2790 )
#    2791 return formatted_output
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\formatting\formatting.py:629, in format_table(table, key, formatter, format_columns, output_all_columns)
#     627 python_formatter = PythonFormatter(features=None)
#     628 if format_columns is None:
# --> 629     return formatter(pa_table, query_type=query_type)
#     630 elif query_type == "column":
#     631     if key in format_columns:
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\formatting\formatting.py:396, in Formatter.__call__(self, pa_table, query_type)
#     394 def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     395     if query_type == "row":
# --> 396         return self.format_row(pa_table)
#     397     elif query_type == "column":
#     398         return self.format_column(pa_table)
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\formatting\formatting.py:437, in PythonFormatter.format_row(self, pa_table)
#     435     return LazyRow(pa_table, self)
#     436 row = self.python_arrow_extractor().extract_row(pa_table)
# --> 437 row = self.python_features_decoder.decode_row(row)
#     438 return row
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\formatting\formatting.py:215, in PythonFeaturesDecoder.decode_row(self, row)
#     214 def decode_row(self, row: dict) -> dict:
# --> 215     return self.features.decode_example(row) if self.features else row
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\features\features.py:1902, in Features.decode_example(self, example, token_per_repo_id)
#    1888 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1889     """Decode example with custom feature decoding.
#    1890
#    1891     Args:
#    (...)
#    1899         `dict[str, Any]`
#    1900     """
# -> 1902     return {
#    1903         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1904         if self._column_requires_decoding[column_name]
#    1905         else value
#    1906         for column_name, (feature, value) in zip_dict(
#    1907             {key: value for key, value in self.items() if key in example}, example
#    1908         )
#    1909     }
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\features\features.py:1903, in <dictcomp>(.0)
#    1888 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1889     """Decode example with custom feature decoding.
#    1890
#    1891     Args:
#    (...)
#    1899         `dict[str, Any]`
#    1900     """
#    1902     return {
# -> 1903         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1904         if self._column_requires_decoding[column_name]
#    1905         else value
#    1906         for column_name, (feature, value) in zip_dict(
#    1907             {key: value for key, value in self.items() if key in example}, example
#    1908         )
#    1909     }
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\features\features.py:1325, in decode_nested_example(schema, obj, token_per_repo_id)
#    1322 elif isinstance(schema, (Audio, Image)):
#    1323     # we pass the token to read and decode files from private repositories in streaming mode
#    1324     if obj is not None and schema.decode:
# -> 1325         return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1326 return obj
#
# File c:\Users\Mehdi\Documents\GitHub\hugging\.venv\Lib\site-packages\datasets\features\image.py:155, in Image.decode_example(self, value, token_per_repo_id)
#     153     import PIL.Image
#     154 else:
# --> 155     raise ImportError("To support decoding images, please install 'Pillow'.")
#     157 if token_per_repo_id is None:
#     158     token_per_repo_id = {}
#
# ImportError: To support decoding images, please install 'Pillow'.
